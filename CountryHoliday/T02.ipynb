# %%
import nest_asyncio; nest_asyncio.apply()
import asyncio
from playwright import async_api
import scrapy

async def main():
    async with async_api.async_playwright() as pw:
        browser = await pw.chromium.launch(headless=True)
        page = await browser.new_page()
        await page.goto("https://www.timeanddate.com/holidays/?allcountries")
        # await page.wait_for_selector("//article[@class='category-list']")

        # selector = await scrapy.Selector(text=page.content())
        print(await page.content())
        await browser.close()

asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[3], line 17
#      14         print(await page.content())
#      15         await browser.close()
# ---> 17 asyncio.run(main())
#
# File /home/Work/venv/lib/python3.12/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File /home/Work/venv/lib/python3.12/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /usr/lib/python3.12/asyncio/futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File /usr/lib/python3.12/asyncio/tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# Cell In[3], line 10, in main()
#       8 browser = await pw.chromium.launch(headless=True)
#       9 page = await browser.new_page()
# ---> 10 await page.goto("https://www.timeanddate.com/holidays/?allcountries")
#      11 # await page.wait_for_selector("//article[@class='category-list']")
#      12
#      13 # selector = await scrapy.Selector(text=page.content())
#      14 print(await page.content())
#
# File /home/Work/venv/lib/python3.12/site-packages/playwright/async_api/_generated.py:9041, in Page.goto(self, url, timeout, wait_until, referer)
#    8980 async def goto(
#    8981     self,
#    8982     url: str,
#    (...)   8988     referer: typing.Optional[str] = None,
#    8989 ) -> typing.Optional["Response"]:
#    8990     """Page.goto
#    8991
#    8992     Returns the main resource response. In case of multiple redirects, the navigation will resolve with the first
#    (...)   9037     Union[Response, None]
#    9038     """
#    9040     return mapping.from_impl_nullable(
# -> 9041         await self._impl_obj.goto(
#    9042             url=url, timeout=timeout, waitUntil=wait_until, referer=referer
#    9043         )
#    9044     )
#
# File /home/Work/venv/lib/python3.12/site-packages/playwright/_impl/_page.py:552, in Page.goto(self, url, timeout, waitUntil, referer)
#     545 async def goto(
#     546     self,
#     547     url: str,
#    (...)    550     referer: str = None,
#     551 ) -> Optional[Response]:
# --> 552     return await self._main_frame.goto(**locals_to_params(locals()))
#
# File /home/Work/venv/lib/python3.12/site-packages/playwright/_impl/_frame.py:153, in Frame.goto(self, url, timeout, waitUntil, referer)
#     143 async def goto(
#     144     self,
#     145     url: str,
#    (...)    148     referer: str = None,
#     149 ) -> Optional[Response]:
#     150     return cast(
#     151         Optional[Response],
#     152         from_nullable_channel(
# --> 153             await self._channel.send(
#     154                 "goto", self._navigation_timeout, locals_to_params(locals())
#     155             )
#     156         ),
#     157     )
#
# File /home/Work/venv/lib/python3.12/site-packages/playwright/_impl/_connection.py:69, in Channel.send(self, method, timeout_calculator, params, is_internal, title)
#      61 async def send(
#      62     self,
#      63     method: str,
#    (...)     67     title: str = None,
#      68 ) -> Any:
# ---> 69     return await self._connection.wrap_api_call(
#      70         lambda: self._inner_send(method, timeout_calculator, params, False),
#      71         is_internal,
#      72         title,
#      73     )
#
# File /home/Work/venv/lib/python3.12/site-packages/playwright/_impl/_connection.py:559, in Connection.wrap_api_call(self, cb, is_internal, title)
#     557     return await cb()
#     558 except Exception as error:
# --> 559     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     560 finally:
#     561     self._api_zone.set(None)
#
# TimeoutError: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://www.timeanddate.com/holidays/?allcountries", waiting until "load"
