# %%
# %%bash
# pip install --no-cache-dir -qU pip wheel
# pip install --no-cache-dir -qU scrapy
# pip check
# Out:
# No broken requirements found.

# %%
import scrapy
import requests

url = 'https://www.timeanddate.com/holidays'
html = requests.get(url).content

sel = scrapy.Selector(text=html)
sel.xpath('//*')
# Out:
# [<Selector query='//*' data='<html lang="en"><head><meta http-equi...'>,
#  <Selector query='//*' data='<head><meta http-equiv="Content-Type"...'>,
#  <Selector query='//*' data='<meta http-equiv="Content-Type" conte...'>,
#  <Selector query='//*' data='<title>Holidays worldwide</title>'>,
#  <Selector query='//*' data='<meta name="description" content="Hol...'>,
#  <Selector query='//*' data='<meta name="robots" content="max-imag...'>,
#  <Selector query='//*' data='<meta property="og:image" content="ht...'>,
#  <Selector query='//*' data='<meta property="og:type" content="web...'>,
#  <Selector query='//*' data='<style>\n@font-face{font-family:iconfo...'>,
#  <Selector query='//*' data='<link rel="preload" href="/common/fon...'>,
#  <Selector query='//*' data='<link rel="preconnect" href="https://...'>,
#  <Selector query='//*' data='<link rel="preload" href="/common/glo...'>,
#  <Selector query='//*' data='<link rel="alternate" hreflang="de" h...'>,
#  <Selector query='//*' data='<link rel="alternate" hreflang="no" h...'>,
#  <Selector query='//*' data='<link rel="preload" href="/common/pre...'>,
#  <Selector query='//*' data='<script src="https://securepubads.g.d...'>,
#  <Selector query='//*' data='<script src="https://c.amazon-adsyste...'>,
#  <Selector query='//*' data='<script src="https://btloader.com/tag...'>,
#  <Selector query='//*' data='<script src="https://secure.quantserv...'>,
#  <Selector query='//*' data='<script>\n\nAdMgr=(function(){var isLog...'>,
#  <Selector query='//*' data='<script src="/common/prebidtad.reg.de...'>,
#  <Selector query='//*' data='<link href="/site.webmanifest" rel="m...'>,
#  <Selector query='//*' data='<link href="/favicon-48x48.png" type=...'>,
#  <Selector query='//*' data='<link href="/favicon-16x16.png" type=...'>,
#  <Selector query='//*' data='<link sizes="32x32" type="image/png" ...'>,
#  <Selector query='//*' data='<link type="text/css" rel="stylesheet...'>,
#  <Selector query='//*' data='<script type="application/ld+json">\n{...'>,
#  <Selector query='//*' data='<link href="/common/index_holiday_14....'>,
#  <Selector query='//*' data='<link href="/common/articles_45.css" ...'>,
#  <Selector query='//*' data='<body class="tpl-custom_bc  "><div id...'>,
#  <Selector query='//*' data='<div id="header__wrapper" class="head...'>,
#  <Selector query='//*' data='<div id="header__inner" class="header...'>,
#  <Selector query='//*' data='<div id="header" class="banner">\n<div...'>,
#  <Selector query='//*' data='<div class="fixed">\n<div id="logo">\n<...'>,
#  <Selector query='//*' data='<div id="logo">\n<a href="/" rel="home...'>,
#  <Selector query='//*' data='<a href="/" rel="home" title="Home pa...'>,
#  <Selector query='//*' data='<div class="tad-logo" role="img" aria...'>,
#  <Selector query='//*' data='<div id="ad-wrap"><div id="ad-wrap2" ...'>,
#  <Selector query='//*' data='<div id="ad-wrap2" class="fixed"><div...'>,
#  <Selector query='//*' data='<div id="ad7"><div id="div-gpt-com-97...'>,
#  <Selector query='//*' data='<div id="div-gpt-com-970x90-head"><sc...'>,
#  <Selector query='//*' data='<script>\nAdMgr.dispSlot(0);\n</script>'>,
#  <Selector query='//*' data='<nav id="nav" class="site-nav-bar">\n<...'>,
#  <Selector query='//*' data='<div class="site-nav-bar__inner fixed...'>,
#  <Selector query='//*' data='<button class="site-nav-bar__button s...'>,
#  <Selector query='//*' data='<i class="i-font i-menu"></i>'>,
#  <Selector query='//*' data='<div class="site-nav-bar__logo">\n<a h...'>,
#  <Selector query='//*' data='<a href="/" rel="home" title="Home pa...'>,
#  <Selector query='//*' data='<img src="//c.tadst.com/gfx/n/logo/lo...'>,
#  <Selector query='//*' data='<button class="site-nav-bar__button" ...'>,
#  <Selector query='//*' data='<i class="i-font i-share"></i>'>,
#  <Selector query='//*' data='<form action="/search/results.html" c...'>,
#  <Selector query='//*' data='<input class="site-nav-bar__search" p...'>,
#  <Selector query='//*' data='<button class="site-nav-bar__button s...'>,
#  <Selector query='//*' data='<div class="site-nav-bar__search-inne...'>,
#  <Selector query='//*' data='<i class="i-font i-search"></i>'>,
#  <Selector query='//*' data='<div class="site-nav-bar__menu-wrap">...'>,
#  <Selector query='//*' data='<div class="site-nav__header">\n<butto...'>,
#  <Selector query='//*' data='<button class="site-nav__login" id="s...'>,
#  <Selector query='//*' data='<button class="site-nav__close" id="s...'>,
#  <Selector query='//*' data='<i class="i-font i-close"></i>'>,
#  <Selector query='//*' data='<ul id="site-nav" class="site-nav">\n<...'>,
#  <Selector query='//*' data='<li class="site-nav__menu "><a href="...'>,
#  <Selector query='//*' data='<a href="/" class="site-nav__title">H...'>,
#  <Selector query='//*' data='<ul class="site-nav__sub-menu"><li cl...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/">Ho...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/news...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/info...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/info...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/comp...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/site...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/topi...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cust...'>,
#  <Selector query='//*' data='<li class="site-nav__menu "><a href="...'>,
#  <Selector query='//*' data='<a href="/worldclock/" class="site-na...'>,
#  <Selector query='//*' data='<ul class="site-nav__sub-menu"><li cl...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/worl...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/worl...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/worl...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/worl...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/worl...'>,
#  <Selector query='//*' data='<li class="site-nav__menu "><a href="...'>,
#  <Selector query='//*' data='<a href="/time/" class="site-nav__tit...'>,
#  <Selector query='//*' data='<ul class="site-nav__sub-menu"><li cl...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/time...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/worl...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/worl...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/worl...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/time...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/time...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/time...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/time...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/time...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/news...'>,
#  <Selector query='//*' data='<li class="site-nav__menu   active"><...'>,
#  <Selector query='//*' data='<a href="/calendar/" class="site-nav_...'>,
#  <Selector query='//*' data='<ul class="site-nav__sub-menu"><li cl...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cale...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cale...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cale...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cale...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cale...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cale...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cale...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cale...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/holi...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/on-t...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cale...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cale...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/date...'>,
#  <Selector query='//*' data='<li class="site-nav__menu "><a href="...'>,
#  <Selector query='//*' data='<a href="/weather/" class="site-nav__...'>,
#  <Selector query='//*' data='<ul class="site-nav__sub-menu"><li cl...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/weat...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/scri...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/scri...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/scri...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/scri...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/scri...'>,
#  <Selector query='//*' data='<li class="site-nav__menu "><a href="...'>,
#  <Selector query='//*' data='<a href="/astronomy/" class="site-nav...'>,
#  <Selector query='//*' data='<ul class="site-nav__sub-menu"><li cl...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/astr...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/sun/...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/moon...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/moon...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/astr...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/astr...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/worl...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/astr...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/ecli...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/ecli...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/ecli...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/live...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cale...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/news...'>,
#  <Selector query='//*' data='<li class="site-nav__menu "><a href="...'>,
#  <Selector query='//*' data='<a href="/counters/" class="site-nav_...'>,
#  <Selector query='//*' data='<ul class="site-nav__sub-menu"><li cl...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/coun...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/stop...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/time...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/coun...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/coun...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/coun...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/coun...'>,
#  <Selector query='//*' data='<li class="site-nav__menu "><a href="...'>,
#  <Selector query='//*' data='<a href="/date/" class="site-nav__tit...'>,
#  <Selector query='//*' data='<ul class="site-nav__sub-menu"><li cl...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/date...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/date...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/date...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/date...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/date...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/date...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/date...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/date...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/worl...'>,
#  <Selector query='//*' data='<li class="site-nav__menu "><a href="...'>,
#  <Selector query='//*' data='<a href="/extra/" class="site-nav__ti...'>,
#  <Selector query='//*' data='<ul class="site-nav__sub-menu"><li cl...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/ios/...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/andr...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cloc...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cloc...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/serv...'>,
#  <Selector query='//*' data='<li class="site-nav__menu "><a href="...'>,
#  <Selector query='//*' data='<a href="/fun/" class="site-nav__titl...'>,
#  <Selector query='//*' data='<ul class="site-nav__sub-menu"><li cl...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/fun"...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cloc...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cloc...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/word...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/holi...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/date...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/date...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/topi...'>,
#  <Selector query='//*' data='<li class="site-nav__menu site-nav__m...'>,
#  <Selector query='//*' data='<a href="/custom/" class="site-nav__t...'>,
#  <Selector query='//*' data='<span class="site-nav__mob-title">My ...'>,
#  <Selector query='//*' data='<i class="i-font i-account_circle sit...'>,
#  <Selector query='//*' data='<ul class="site-nav__sub-menu"><li cl...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cust...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a id="pop...'>,
#  <Selector query='//*' data='<a id="popchi" class="site-nav__link"...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cust...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cale...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/worl...'>,
#  <Selector query='//*' data='<li class="site-nav__item site-nav__i...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/cust...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a class="...'>,
#  <Selector query='//*' data='<a class="site-nav__link" href="/serv...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a id="pop...'>,
#  <Selector query='//*' data='<a id="poplogin" class="site-nav__lin...'>,
#  <Selector query='//*' data='<li class="site-nav__item"><a id="pop...'>,
#  <Selector query='//*' data='<a id="popreg" class="site-nav__link"...'>,
#  <Selector query='//*' data='<div class="site-nav-bar__blur" id="s...'>,
#  <Selector query='//*' data='<div id="po1" class="po"></div>'>,
#  <Selector query='//*' data='<div id="mpo"></div>'>,
#  <Selector query='//*' data='<div id="anw" class="alert-notice__wr...'>,
#  <Selector query='//*' data='<div class="main-content-div"><script...'>,
#  <Selector query='//*' data='<script>\nwindow.TAD=window.TAD||{};TA...'>,
#  <Selector query='//*' data='<div class="fixed"></div>'>,
#  <Selector query='//*' data='<div class="main-content-div"><header...'>,
#  <Selector query='//*' data='<header class="bn-header bn-header--h...'>,
#  <Selector query='//*' data='<div class="row socrow"><div id="bc" ...'>,
#  <Selector query='//*' data='<div id="bc" class="fixed"><div id="b...'>,
#  <Selector query='//*' data='<div id="bct"><a target="_top" href="...'>,
#  <Selector query='//*' data='<a target="_top" href="/" class="fx">...'>,
#  <Selector query='//*' data='<a target="_top" href="/calendar/" cl...'>,
#  <Selector query='//*' data='<div class="bn-header__wrap fixed"><d...'>,
#  <Selector query='//*' data='<div class="headline-banner headline-...'>,
#  <Selector query='//*' data='<section class="headline-banner__wrap...'>,
#  <Selector query='//*' data='<div class="headline-banner__content"...'>,
#  <Selector query='//*' data='<h1 class="headline-banner__title">Ho...'>,
#  <Selector query='//*' data='<p class="headline-banner__brief">Pub...'>,
#  <Selector query='//*' data='<section class="headline-banner__extr...'>,
#  <Selector query='//*' data='<form action="/holidays/search.html" ...'>,
#  <Selector query='//*' data='<input type="search" autocomplete="of...'>,
#  <Selector query='//*' data='<button type="submit" class="picker-c...'>,
#  <Selector query='//*' data='<i class="i-font i-search"></i>'>,
#  <Selector query='//*' data='<section class="bn-header__extra"><di...'>,
#  <Selector query='//*' data='<div class="fixed"><strong>Suggested ...'>,
#  <Selector query='//*' data='<strong>Suggested countries: </strong>'>,
#  <Selector query='//*' data='<a href="/holidays/us/">United States...'>,
#  <Selector query='//*' data='<a href="/holidays/australia/">Austra...'>,
#  <Selector query='//*' data='<a href="/holidays/canada/">Canada</a>'>,
#  <Selector query='//*' data='<a href="/holidays/uk/">United Kingdo...'>,
#  <Selector query='//*' data='<main class="content__main pdflexi"><...'>,
#  <Selector query='//*' data='<div class="fixed"><section class="co...'>,
#  <Selector query='//*' data='<section class="content__body content...'>,
#  <Selector query='//*' data='<nav class="table-data__jumplist" dat...'>,
#  <Selector query='//*' data='<span class="table-data__jumplist-lab...'>,
#  <Selector query='//*' data='<i class="i-font i-jump_down"></i>'>,
#  <Selector query='//*' data='<a href="#A">A</a>'>,
#  <Selector query='//*' data='<a href="#B">B</a>'>,
#  <Selector query='//*' data='<a href="#C">C</a>'>,
#  <Selector query='//*' data='<a href="#D">D</a>'>,
#  <Selector query='//*' data='<a href="#E">E</a>'>,
#  <Selector query='//*' data='<a href="#F">F</a>'>,
#  <Selector query='//*' data='<a href="#G">G</a>'>,
#  <Selector query='//*' data='<a href="#H">H</a>'>,
#  <Selector query='//*' data='<a href="#I">I</a>'>,
#  <Selector query='//*' data='<a href="#J">J</a>'>,
#  <Selector query='//*' data='<a href="#K">K</a>'>,
#  <Selector query='//*' data='<a href="#L">L</a>'>,
#  <Selector query='//*' data='<a href="#M">M</a>'>,
#  <Selector query='//*' data='<a href="#N">N</a>'>,
#  <Selector query='//*' data='<a href="#O">O</a>'>,
#  <Selector query='//*' data='<a href="#P">P</a>'>,
#  <Selector query='//*' data='<a href="#Q">Q</a>'>,
#  <Selector query='//*' data='<a href="#R">R</a>'>,
#  <Selector query='//*' data='<a href="#S">S</a>'>,
#  <Selector query='//*' data='<a href="#T">T</a>'>,
#  <Selector query='//*' data='<a href="#U">U</a>'>,
#  <Selector query='//*' data='<a href="#V">V</a>'>,
#  <Selector query='//*' data='<a href="#W">W</a>'>,
#  <Selector query='//*' data='<a href="#Y">Y</a>'>,
#  <Selector query='//*' data='<a href="#Z">Z</a>'>,
#  <Selector query='//*' data='<article class="category-list"><secti...'>,
#  <Selector query='//*' data='<section id="A"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">A...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/afghanistan/">...'>,
#  <Selector query='//*' data='<a href="/holidays/afghanistan/">Afgh...'>,
#  <Selector query='//*' data='<li><a href="/holidays/albania/">Alba...'>,
#  <Selector query='//*' data='<a href="/holidays/albania/">Albania</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/algeria/">Alge...'>,
#  <Selector query='//*' data='<a href="/holidays/algeria/">Algeria</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/american-samoa...'>,
#  <Selector query='//*' data='<a href="/holidays/american-samoa/">A...'>,
#  <Selector query='//*' data='<li><a href="/holidays/andorra/">Ando...'>,
#  <Selector query='//*' data='<a href="/holidays/andorra/">Andorra</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/angola/">Angol...'>,
#  <Selector query='//*' data='<a href="/holidays/angola/">Angola</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/anguilla/">Ang...'>,
#  <Selector query='//*' data='<a href="/holidays/anguilla/">Anguill...'>,
#  <Selector query='//*' data='<li><a href="/holidays/antigua-and-ba...'>,
#  <Selector query='//*' data='<a href="/holidays/antigua-and-barbud...'>,
#  <Selector query='//*' data='<li><a href="/holidays/argentina/">Ar...'>,
#  <Selector query='//*' data='<a href="/holidays/argentina/">Argent...'>,
#  <Selector query='//*' data='<li><a href="/holidays/armenia/">Arme...'>,
#  <Selector query='//*' data='<a href="/holidays/armenia/">Armenia</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/aruba/">Aruba<...'>,
#  <Selector query='//*' data='<a href="/holidays/aruba/">Aruba</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/australia/">Au...'>,
#  <Selector query='//*' data='<a href="/holidays/australia/">Austra...'>,
#  <Selector query='//*' data='<li><a href="/holidays/austria/">Aust...'>,
#  <Selector query='//*' data='<a href="/holidays/austria/">Austria</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/azerbaijan/">A...'>,
#  <Selector query='//*' data='<a href="/holidays/azerbaijan/">Azerb...'>,
#  <Selector query='//*' data='<section id="B"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">B...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/bahrain/">Bahr...'>,
#  <Selector query='//*' data='<a href="/holidays/bahrain/">Bahrain</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/bangladesh/">B...'>,
#  <Selector query='//*' data='<a href="/holidays/bangladesh/">Bangl...'>,
#  <Selector query='//*' data='<li><a href="/holidays/barbados/">Bar...'>,
#  <Selector query='//*' data='<a href="/holidays/barbados/">Barbado...'>,
#  <Selector query='//*' data='<li><a href="/holidays/belarus/">Bela...'>,
#  <Selector query='//*' data='<a href="/holidays/belarus/">Belarus</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/belgium/">Belg...'>,
#  <Selector query='//*' data='<a href="/holidays/belgium/">Belgium</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/belize/">Beliz...'>,
#  <Selector query='//*' data='<a href="/holidays/belize/">Belize</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/benin/">Benin<...'>,
#  <Selector query='//*' data='<a href="/holidays/benin/">Benin</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/bermuda/">Berm...'>,
#  <Selector query='//*' data='<a href="/holidays/bermuda/">Bermuda</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/bhutan/">Bhuta...'>,
#  <Selector query='//*' data='<a href="/holidays/bhutan/">Bhutan</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/bolivia/">Boli...'>,
#  <Selector query='//*' data='<a href="/holidays/bolivia/">Bolivia</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/bosnia/">Bosni...'>,
#  <Selector query='//*' data='<a href="/holidays/bosnia/">Bosnia an...'>,
#  <Selector query='//*' data='<li><a href="/holidays/botswana/">Bot...'>,
#  <Selector query='//*' data='<a href="/holidays/botswana/">Botswan...'>,
#  <Selector query='//*' data='<li><a href="/holidays/brazil/">Brazi...'>,
#  <Selector query='//*' data='<a href="/holidays/brazil/">Brazil</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/british-virgin...'>,
#  <Selector query='//*' data='<a href="/holidays/british-virgin-isl...'>,
#  <Selector query='//*' data='<li><a href="/holidays/brunei/">Brune...'>,
#  <Selector query='//*' data='<a href="/holidays/brunei/">Brunei</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/bulgaria/">Bul...'>,
#  <Selector query='//*' data='<a href="/holidays/bulgaria/">Bulgari...'>,
#  <Selector query='//*' data='<li><a href="/holidays/burkina-faso/"...'>,
#  <Selector query='//*' data='<a href="/holidays/burkina-faso/">Bur...'>,
#  <Selector query='//*' data='<li><a href="/holidays/burundi/">Buru...'>,
#  <Selector query='//*' data='<a href="/holidays/burundi/">Burundi</a>'>,
#  <Selector query='//*' data='<section class="collapsible" data-tad...'>,
#  <Selector query='//*' data='<h4 class="collapsible__more"><a href...'>,
#  <Selector query='//*' data='<a href="#">Show more <i class="i-fon...'>,
#  <Selector query='//*' data='<i class="i-font i-expand_more"></i>'>,
#  <Selector query='//*' data='<div class="collapsible__content"><se...'>,
#  <Selector query='//*' data='<section id="C"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">C...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/cape-verde/">C...'>,
#  <Selector query='//*' data='<a href="/holidays/cape-verde/">Cabo ...'>,
#  <Selector query='//*' data='<li><a href="/holidays/cambodia/">Cam...'>,
#  <Selector query='//*' data='<a href="/holidays/cambodia/">Cambodi...'>,
#  <Selector query='//*' data='<li><a href="/holidays/cameroon/">Cam...'>,
#  <Selector query='//*' data='<a href="/holidays/cameroon/">Cameroo...'>,
#  <Selector query='//*' data='<li><a href="/holidays/canada/">Canad...'>,
#  <Selector query='//*' data='<a href="/holidays/canada/">Canada</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/cayman-islands...'>,
#  <Selector query='//*' data='<a href="/holidays/cayman-islands/">C...'>,
#  <Selector query='//*' data='<li><a href="/holidays/central-africa...'>,
#  <Selector query='//*' data='<a href="/holidays/central-african-re...'>,
#  <Selector query='//*' data='<li><a href="/holidays/chad/">Chad</a...'>,
#  <Selector query='//*' data='<a href="/holidays/chad/">Chad</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/chile/">Chile<...'>,
#  <Selector query='//*' data='<a href="/holidays/chile/">Chile</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/china/">China<...'>,
#  <Selector query='//*' data='<a href="/holidays/china/">China</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/colombia/">Col...'>,
#  <Selector query='//*' data='<a href="/holidays/colombia/">Colombi...'>,
#  <Selector query='//*' data='<li><a href="/holidays/comores/">Como...'>,
#  <Selector query='//*' data='<a href="/holidays/comores/">Comoros</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/republic-of-th...'>,
#  <Selector query='//*' data='<a href="/holidays/republic-of-the-co...'>,
#  <Selector query='//*' data='<li><a href="/holidays/dr-congo/">Con...'>,
#  <Selector query='//*' data='<a href="/holidays/dr-congo/">Congo D...'>,
#  <Selector query='//*' data='<li><a href="/holidays/cook-islands/"...'>,
#  <Selector query='//*' data='<a href="/holidays/cook-islands/">Coo...'>,
#  <Selector query='//*' data='<li><a href="/holidays/costa-rica/">C...'>,
#  <Selector query='//*' data='<a href="/holidays/costa-rica/">Costa...'>,
#  <Selector query='//*' data='<li><a href="/holidays/ivory-coast/">...'>,
#  <Selector query='//*' data='<a href="/holidays/ivory-coast/">Cote...'>,
#  <Selector query='//*' data='<li><a href="/holidays/croatia/">Croa...'>,
#  <Selector query='//*' data='<a href="/holidays/croatia/">Croatia</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/cuba/">Cuba</a...'>,
#  <Selector query='//*' data='<a href="/holidays/cuba/">Cuba</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/curacao/">Cura...'>,
#  <Selector query='//*' data='<a href="/holidays/curacao/">Curaçao</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/cyprus/">Cypru...'>,
#  <Selector query='//*' data='<a href="/holidays/cyprus/">Cyprus</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/czech/">Czechi...'>,
#  <Selector query='//*' data='<a href="/holidays/czech/">Czechia</a>'>,
#  <Selector query='//*' data='<section id="D"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">D...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/denmark/">Denm...'>,
#  <Selector query='//*' data='<a href="/holidays/denmark/">Denmark</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/djibouti/">Dji...'>,
#  <Selector query='//*' data='<a href="/holidays/djibouti/">Djibout...'>,
#  <Selector query='//*' data='<li><a href="/holidays/dominica/">Dom...'>,
#  <Selector query='//*' data='<a href="/holidays/dominica/">Dominic...'>,
#  <Selector query='//*' data='<li><a href="/holidays/dominican-repu...'>,
#  <Selector query='//*' data='<a href="/holidays/dominican-republic...'>,
#  <Selector query='//*' data='<section id="E"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">E...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/timor-leste/">...'>,
#  <Selector query='//*' data='<a href="/holidays/timor-leste/">East...'>,
#  <Selector query='//*' data='<li><a href="/holidays/ecuador/">Ecua...'>,
#  <Selector query='//*' data='<a href="/holidays/ecuador/">Ecuador</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/egypt/">Egypt<...'>,
#  <Selector query='//*' data='<a href="/holidays/egypt/">Egypt</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/el-salvador/">...'>,
#  <Selector query='//*' data='<a href="/holidays/el-salvador/">El S...'>,
#  <Selector query='//*' data='<li><a href="/holidays/guineaecuatori...'>,
#  <Selector query='//*' data='<a href="/holidays/guineaecuatorial/"...'>,
#  <Selector query='//*' data='<li><a href="/holidays/eritrea/">Erit...'>,
#  <Selector query='//*' data='<a href="/holidays/eritrea/">Eritrea</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/estonia/">Esto...'>,
#  <Selector query='//*' data='<a href="/holidays/estonia/">Estonia</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/swaziland/">Es...'>,
#  <Selector query='//*' data='<a href="/holidays/swaziland/">Eswati...'>,
#  <Selector query='//*' data='<li><a href="/holidays/ethiopia/">Eth...'>,
#  <Selector query='//*' data='<a href="/holidays/ethiopia/">Ethiopi...'>,
#  <Selector query='//*' data='<section id="F"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">F...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/falkland-islan...'>,
#  <Selector query='//*' data='<a href="/holidays/falkland-islands/"...'>,
#  <Selector query='//*' data='<li><a href="/holidays/faroe-islands/...'>,
#  <Selector query='//*' data='<a href="/holidays/faroe-islands/">Fa...'>,
#  <Selector query='//*' data='<li><a href="/holidays/fiji/">Fiji</a...'>,
#  <Selector query='//*' data='<a href="/holidays/fiji/">Fiji</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/finland/">Finl...'>,
#  <Selector query='//*' data='<a href="/holidays/finland/">Finland</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/france/">Franc...'>,
#  <Selector query='//*' data='<a href="/holidays/france/">France</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/french-guiana/...'>,
#  <Selector query='//*' data='<a href="/holidays/french-guiana/">Fr...'>,
#  <Selector query='//*' data='<li><a href="/holidays/french-polynes...'>,
#  <Selector query='//*' data='<a href="/holidays/french-polynesia/"...'>,
#  <Selector query='//*' data='<section id="G"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">G...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/gabon/">Gabon<...'>,
#  <Selector query='//*' data='<a href="/holidays/gabon/">Gabon</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/gambia/">Gambi...'>,
#  <Selector query='//*' data='<a href="/holidays/gambia/">Gambia</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/georgia/">Geor...'>,
#  <Selector query='//*' data='<a href="/holidays/georgia/">Georgia</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/germany/">Germ...'>,
#  <Selector query='//*' data='<a href="/holidays/germany/">Germany</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/ghana/">Ghana<...'>,
#  <Selector query='//*' data='<a href="/holidays/ghana/">Ghana</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/gibraltar/">Gi...'>,
#  <Selector query='//*' data='<a href="/holidays/gibraltar/">Gibral...'>,
#  <Selector query='//*' data='<li><a href="/holidays/greece/">Greec...'>,
#  <Selector query='//*' data='<a href="/holidays/greece/">Greece</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/greenland/">Gr...'>,
#  <Selector query='//*' data='<a href="/holidays/greenland/">Greenl...'>,
#  <Selector query='//*' data='<li><a href="/holidays/grenada/">Gren...'>,
#  <Selector query='//*' data='<a href="/holidays/grenada/">Grenada</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/guadeloupe/">G...'>,
#  <Selector query='//*' data='<a href="/holidays/guadeloupe/">Guade...'>,
#  <Selector query='//*' data='<li><a href="/holidays/guam/">Guam</a...'>,
#  <Selector query='//*' data='<a href="/holidays/guam/">Guam</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/guatemala/">Gu...'>,
#  <Selector query='//*' data='<a href="/holidays/guatemala/">Guatem...'>,
#  <Selector query='//*' data='<li><a href="/holidays/guernsey/">Gue...'>,
#  <Selector query='//*' data='<a href="/holidays/guernsey/">Guernse...'>,
#  <Selector query='//*' data='<li><a href="/holidays/guinea/">Guine...'>,
#  <Selector query='//*' data='<a href="/holidays/guinea/">Guinea</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/guinea-bissau/...'>,
#  <Selector query='//*' data='<a href="/holidays/guinea-bissau/">Gu...'>,
#  <Selector query='//*' data='<li><a href="/holidays/guyana/">Guyan...'>,
#  <Selector query='//*' data='<a href="/holidays/guyana/">Guyana</a>'>,
#  <Selector query='//*' data='<section id="H"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">H...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/haiti/">Haiti<...'>,
#  <Selector query='//*' data='<a href="/holidays/haiti/">Haiti</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/honduras/">Hon...'>,
#  <Selector query='//*' data='<a href="/holidays/honduras/">Hondura...'>,
#  <Selector query='//*' data='<li><a href="/holidays/hong-kong/">Ho...'>,
#  <Selector query='//*' data='<a href="/holidays/hong-kong/">Hong K...'>,
#  <Selector query='//*' data='<li><a href="/holidays/hungary/">Hung...'>,
#  <Selector query='//*' data='<a href="/holidays/hungary/">Hungary</a>'>,
#  <Selector query='//*' data='<section id="I"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">I...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/iceland/">Icel...'>,
#  <Selector query='//*' data='<a href="/holidays/iceland/">Iceland</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/india/">India<...'>,
#  <Selector query='//*' data='<a href="/holidays/india/">India</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/indonesia/">In...'>,
#  <Selector query='//*' data='<a href="/holidays/indonesia/">Indone...'>,
#  <Selector query='//*' data='<li><a href="/holidays/iran/">Iran</a...'>,
#  <Selector query='//*' data='<a href="/holidays/iran/">Iran</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/iraq/">Iraq</a...'>,
#  <Selector query='//*' data='<a href="/holidays/iraq/">Iraq</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/ireland/">Irel...'>,
#  <Selector query='//*' data='<a href="/holidays/ireland/">Ireland</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/isle-of-man/">...'>,
#  <Selector query='//*' data='<a href="/holidays/isle-of-man/">Isle...'>,
#  <Selector query='//*' data='<li><a href="/holidays/israel/">Israe...'>,
#  <Selector query='//*' data='<a href="/holidays/israel/">Israel</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/italy/">Italy<...'>,
#  <Selector query='//*' data='<a href="/holidays/italy/">Italy</a>'>,
#  <Selector query='//*' data='<section id="J"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">J...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/jamaica/">Jama...'>,
#  <Selector query='//*' data='<a href="/holidays/jamaica/">Jamaica</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/japan/">Japan<...'>,
#  <Selector query='//*' data='<a href="/holidays/japan/">Japan</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/jersey/">Jerse...'>,
#  <Selector query='//*' data='<a href="/holidays/jersey/">Jersey</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/jordan/">Jorda...'>,
#  <Selector query='//*' data='<a href="/holidays/jordan/">Jordan</a>'>,
#  <Selector query='//*' data='<section id="K"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">K...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/kazakhstan/">K...'>,
#  <Selector query='//*' data='<a href="/holidays/kazakhstan/">Kazak...'>,
#  <Selector query='//*' data='<li><a href="/holidays/kenya/">Kenya<...'>,
#  <Selector query='//*' data='<a href="/holidays/kenya/">Kenya</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/kiribati/">Kir...'>,
#  <Selector query='//*' data='<a href="/holidays/kiribati/">Kiribat...'>,
#  <Selector query='//*' data='<li><a href="/holidays/kosovo/">Kosov...'>,
#  <Selector query='//*' data='<a href="/holidays/kosovo/">Kosovo</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/kuwait/">Kuwai...'>,
#  <Selector query='//*' data='<a href="/holidays/kuwait/">Kuwait</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/kyrgyzstan/">K...'>,
#  <Selector query='//*' data='<a href="/holidays/kyrgyzstan/">Kyrgy...'>,
#  <Selector query='//*' data='<section id="L"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">L...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/laos/">Laos</a...'>,
#  <Selector query='//*' data='<a href="/holidays/laos/">Laos</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/latvia/">Latvi...'>,
#  <Selector query='//*' data='<a href="/holidays/latvia/">Latvia</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/lebanon/">Leba...'>,
#  <Selector query='//*' data='<a href="/holidays/lebanon/">Lebanon</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/lesotho/">Leso...'>,
#  <Selector query='//*' data='<a href="/holidays/lesotho/">Lesotho</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/liberia/">Libe...'>,
#  <Selector query='//*' data='<a href="/holidays/liberia/">Liberia</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/libya/">Libya<...'>,
#  <Selector query='//*' data='<a href="/holidays/libya/">Libya</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/liechtenstein/...'>,
#  <Selector query='//*' data='<a href="/holidays/liechtenstein/">Li...'>,
#  <Selector query='//*' data='<li><a href="/holidays/lithuania/">Li...'>,
#  <Selector query='//*' data='<a href="/holidays/lithuania/">Lithua...'>,
#  <Selector query='//*' data='<li><a href="/holidays/luxembourg/">L...'>,
#  <Selector query='//*' data='<a href="/holidays/luxembourg/">Luxem...'>,
#  <Selector query='//*' data='<section id="M"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">M...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/macau/">Macau<...'>,
#  <Selector query='//*' data='<a href="/holidays/macau/">Macau</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/madagascar/">M...'>,
#  <Selector query='//*' data='<a href="/holidays/madagascar/">Madag...'>,
#  <Selector query='//*' data='<li><a href="/holidays/malawi/">Malaw...'>,
#  <Selector query='//*' data='<a href="/holidays/malawi/">Malawi</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/malaysia/">Mal...'>,
#  <Selector query='//*' data='<a href="/holidays/malaysia/">Malaysi...'>,
#  <Selector query='//*' data='<li><a href="/holidays/maldives/">Mal...'>,
#  <Selector query='//*' data='<a href="/holidays/maldives/">Maldive...'>,
#  <Selector query='//*' data='<li><a href="/holidays/mali/">Mali</a...'>,
#  <Selector query='//*' data='<a href="/holidays/mali/">Mali</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/malta/">Malta<...'>,
#  <Selector query='//*' data='<a href="/holidays/malta/">Malta</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/marshall-islan...'>,
#  <Selector query='//*' data='<a href="/holidays/marshall-islands/"...'>,
#  <Selector query='//*' data='<li><a href="/holidays/martinique/">M...'>,
#  <Selector query='//*' data='<a href="/holidays/martinique/">Marti...'>,
#  <Selector query='//*' data='<li><a href="/holidays/mauritania/">M...'>,
#  <Selector query='//*' data='<a href="/holidays/mauritania/">Mauri...'>,
#  <Selector query='//*' data='<li><a href="/holidays/mauritius/">Ma...'>,
#  <Selector query='//*' data='<a href="/holidays/mauritius/">Maurit...'>,
#  <Selector query='//*' data='<li><a href="/holidays/mayotte/">Mayo...'>,
#  <Selector query='//*' data='<a href="/holidays/mayotte/">Mayotte</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/mexico/">Mexic...'>,
#  <Selector query='//*' data='<a href="/holidays/mexico/">Mexico</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/micronesia/">M...'>,
#  <Selector query='//*' data='<a href="/holidays/micronesia/">Micro...'>,
#  <Selector query='//*' data='<li><a href="/holidays/moldova/">Mold...'>,
#  <Selector query='//*' data='<a href="/holidays/moldova/">Moldova</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/monaco/">Monac...'>,
#  <Selector query='//*' data='<a href="/holidays/monaco/">Monaco</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/mongolia/">Mon...'>,
# ...
#  <Selector query='//*' data='<a href="/holidays/sao-tome-and-princ...'>,
#  <Selector query='//*' data='<li><a href="/holidays/saudi-arabia/"...'>,
#  <Selector query='//*' data='<a href="/holidays/saudi-arabia/">Sau...'>,
#  <Selector query='//*' data='<li><a href="/holidays/senegal/">Sene...'>,
#  <Selector query='//*' data='<a href="/holidays/senegal/">Senegal</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/serbia/">Serbi...'>,
#  <Selector query='//*' data='<a href="/holidays/serbia/">Serbia</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/seychelles/">S...'>,
#  <Selector query='//*' data='<a href="/holidays/seychelles/">Seych...'>,
#  <Selector query='//*' data='<li><a href="/holidays/sierra-leone/"...'>,
#  <Selector query='//*' data='<a href="/holidays/sierra-leone/">Sie...'>,
#  <Selector query='//*' data='<li><a href="/holidays/singapore/">Si...'>,
#  <Selector query='//*' data='<a href="/holidays/singapore/">Singap...'>,
#  <Selector query='//*' data='<li><a href="/holidays/sint-maarten/"...'>,
#  <Selector query='//*' data='<a href="/holidays/sint-maarten/">Sin...'>,
#  <Selector query='//*' data='<li><a href="/holidays/slovakia/">Slo...'>,
#  <Selector query='//*' data='<a href="/holidays/slovakia/">Slovaki...'>,
#  <Selector query='//*' data='<li><a href="/holidays/slovenia/">Slo...'>,
#  <Selector query='//*' data='<a href="/holidays/slovenia/">Sloveni...'>,
#  <Selector query='//*' data='<li><a href="/holidays/solomon-island...'>,
#  <Selector query='//*' data='<a href="/holidays/solomon-islands/">...'>,
#  <Selector query='//*' data='<li><a href="/holidays/somalia/">Soma...'>,
#  <Selector query='//*' data='<a href="/holidays/somalia/">Somalia</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/south-africa/"...'>,
#  <Selector query='//*' data='<a href="/holidays/south-africa/">Sou...'>,
#  <Selector query='//*' data='<li><a href="/holidays/south-korea/">...'>,
#  <Selector query='//*' data='<a href="/holidays/south-korea/">Sout...'>,
#  <Selector query='//*' data='<li><a href="/holidays/south-sudan/">...'>,
#  <Selector query='//*' data='<a href="/holidays/south-sudan/">Sout...'>,
#  <Selector query='//*' data='<li><a href="/holidays/spain/">Spain<...'>,
#  <Selector query='//*' data='<a href="/holidays/spain/">Spain</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/sri-lanka/">Sr...'>,
#  <Selector query='//*' data='<a href="/holidays/sri-lanka/">Sri La...'>,
#  <Selector query='//*' data='<li><a href="/holidays/saint-barthele...'>,
#  <Selector query='//*' data='<a href="/holidays/saint-barthelemy/"...'>,
#  <Selector query='//*' data='<li><a href="/holidays/sudan/">Sudan<...'>,
#  <Selector query='//*' data='<a href="/holidays/sudan/">Sudan</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/suriname/">Sur...'>,
#  <Selector query='//*' data='<a href="/holidays/suriname/">Surinam...'>,
#  <Selector query='//*' data='<li><a href="/holidays/sweden/">Swede...'>,
#  <Selector query='//*' data='<a href="/holidays/sweden/">Sweden</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/switzerland/">...'>,
#  <Selector query='//*' data='<a href="/holidays/switzerland/">Swit...'>,
#  <Selector query='//*' data='<li><a href="/holidays/syria/">Syria<...'>,
#  <Selector query='//*' data='<a href="/holidays/syria/">Syria</a>'>,
#  <Selector query='//*' data='<section id="T"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">T...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/taiwan/">Taiwa...'>,
#  <Selector query='//*' data='<a href="/holidays/taiwan/">Taiwan</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/tajikistan/">T...'>,
#  <Selector query='//*' data='<a href="/holidays/tajikistan/">Tajik...'>,
#  <Selector query='//*' data='<li><a href="/holidays/tanzania/">Tan...'>,
#  <Selector query='//*' data='<a href="/holidays/tanzania/">Tanzani...'>,
#  <Selector query='//*' data='<li><a href="/holidays/thailand/">Tha...'>,
#  <Selector query='//*' data='<a href="/holidays/thailand/">Thailan...'>,
#  <Selector query='//*' data='<li><a href="/holidays/bahamas/">The ...'>,
#  <Selector query='//*' data='<a href="/holidays/bahamas/">The Baha...'>,
#  <Selector query='//*' data='<li><a href="/holidays/togo/">Togo</a...'>,
#  <Selector query='//*' data='<a href="/holidays/togo/">Togo</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/tonga/">Tonga<...'>,
#  <Selector query='//*' data='<a href="/holidays/tonga/">Tonga</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/trinidad/">Tri...'>,
#  <Selector query='//*' data='<a href="/holidays/trinidad/">Trinida...'>,
#  <Selector query='//*' data='<li><a href="/holidays/tunisia/">Tuni...'>,
#  <Selector query='//*' data='<a href="/holidays/tunisia/">Tunisia</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/turkey/">Turke...'>,
#  <Selector query='//*' data='<a href="/holidays/turkey/">Turkey</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/turkmenistan/"...'>,
#  <Selector query='//*' data='<a href="/holidays/turkmenistan/">Tur...'>,
#  <Selector query='//*' data='<li><a href="/holidays/turks-and-caic...'>,
#  <Selector query='//*' data='<a href="/holidays/turks-and-caicos-i...'>,
#  <Selector query='//*' data='<li><a href="/holidays/tuvalu/">Tuval...'>,
#  <Selector query='//*' data='<a href="/holidays/tuvalu/">Tuvalu</a>'>,
#  <Selector query='//*' data='<section id="U"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">U...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/uganda/">Ugand...'>,
#  <Selector query='//*' data='<a href="/holidays/uganda/">Uganda</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/ukraine/">Ukra...'>,
#  <Selector query='//*' data='<a href="/holidays/ukraine/">Ukraine</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/united-arab-em...'>,
#  <Selector query='//*' data='<a href="/holidays/united-arab-emirat...'>,
#  <Selector query='//*' data='<li><a href="/holidays/uk/">United Ki...'>,
#  <Selector query='//*' data='<a href="/holidays/uk/">United Kingdo...'>,
#  <Selector query='//*' data='<li><a href="/holidays/us/">United St...'>,
#  <Selector query='//*' data='<a href="/holidays/us/">United States...'>,
#  <Selector query='//*' data='<li><a href="/holidays/uruguay/">Urug...'>,
#  <Selector query='//*' data='<a href="/holidays/uruguay/">Uruguay</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/united-states-...'>,
#  <Selector query='//*' data='<a href="/holidays/united-states-virg...'>,
#  <Selector query='//*' data='<li><a href="/holidays/uzbekistan/">U...'>,
#  <Selector query='//*' data='<a href="/holidays/uzbekistan/">Uzbek...'>,
#  <Selector query='//*' data='<section id="V"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">V...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/vanuatu/">Vanu...'>,
#  <Selector query='//*' data='<a href="/holidays/vanuatu/">Vanuatu</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/vatican-city-s...'>,
#  <Selector query='//*' data='<a href="/holidays/vatican-city-state...'>,
#  <Selector query='//*' data='<li><a href="/holidays/venezuela/">Ve...'>,
#  <Selector query='//*' data='<a href="/holidays/venezuela/">Venezu...'>,
#  <Selector query='//*' data='<li><a href="/holidays/vietnam/">Viet...'>,
#  <Selector query='//*' data='<a href="/holidays/vietnam/">Vietnam</a>'>,
#  <Selector query='//*' data='<section id="W"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">W...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/wallis-and-fut...'>,
#  <Selector query='//*' data='<a href="/holidays/wallis-and-futuna/...'>,
#  <Selector query='//*' data='<section id="Y"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">Y...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/yemen/">Yemen<...'>,
#  <Selector query='//*' data='<a href="/holidays/yemen/">Yemen</a>'>,
#  <Selector query='//*' data='<section id="Z"><h3 class="category-l...'>,
#  <Selector query='//*' data='<h3 class="category-list__category">Z...'>,
#  <Selector query='//*' data='<ul class="category-list__list"><li><...'>,
#  <Selector query='//*' data='<li><a href="/holidays/zambia/">Zambi...'>,
#  <Selector query='//*' data='<a href="/holidays/zambia/">Zambia</a>'>,
#  <Selector query='//*' data='<li><a href="/holidays/zimbabwe/">Zim...'>,
#  <Selector query='//*' data='<a href="/holidays/zimbabwe/">Zimbabw...'>,
#  <Selector query='//*' data='<article class="table-data"><section ...'>,
#  <Selector query='//*' data='<section class="table-data__table"><h...'>,
#  <Selector query='//*' data='<h2 id="international">International ...'>,
#  <Selector query='//*' data='<table class="table table--left table...'>,
#  <Selector query='//*' data='<thead><tr><th>Date</th><th>\xa0</th><th...'>,
#  <Selector query='//*' data='<tr><th>Date</th><th>\xa0</th><th>Name</...'>,
#  <Selector query='//*' data='<th>Date</th>'>,
#  <Selector query='//*' data='<th>\xa0</th>'>,
#  <Selector query='//*' data='<th>Name</th>'>,
#  <Selector query='//*' data='<th>Where</th>'>,
#  <Selector query='//*' data='<tbody><tr><th class="nw">Sep 6</th><...'>,
#  <Selector query='//*' data='<tr><th class="nw">Sep 6</th><th clas...'>,
#  <Selector query='//*' data='<th class="nw">Sep 6</th>'>,
#  <Selector query='//*' data='<th class="nw">Wednesday</th>'>,
#  <Selector query='//*' data='<td>Janmashtami</td>'>,
#  <Selector query='//*' data='<td><a href="/holidays/bangladesh/jan...'>,
#  <Selector query='//*' data='<a href="/holidays/bangladesh/janmash...'>,
#  <Selector query='//*' data='<a href="/holidays/indonesia/hindu-ja...'>,
#  <Selector query='//*' data='<a href="/holidays/myanmar/hindu-janm...'>,
#  <Selector query='//*' data='<a href="/holidays/nepal/shree-krishn...'>,
#  <Selector query='//*' data='<a href="/holidays/us/hindu-janmashta...'>,
#  <Selector query='//*' data='<tr><td colspan="2" class="nw">\xa0</td>...'>,
#  <Selector query='//*' data='<td colspan="2" class="nw">\xa0</td>'>,
#  <Selector query='//*' data='<td>Unification Day</td>'>,
#  <Selector query='//*' data='<td><a href="/holidays/bulgaria/unifi...'>,
#  <Selector query='//*' data='<a href="/holidays/bulgaria/unificati...'>,
#  <Selector query='//*' data='<tr><td colspan="2" class="nw">\xa0</td>...'>,
#  <Selector query='//*' data='<td colspan="2" class="nw">\xa0</td>'>,
#  <Selector query='//*' data='<td>Janmashtami (Smarta)</td>'>,
#  <Selector query='//*' data='<td><a href="/holidays/india/janmasht...'>,
#  <Selector query='//*' data='<a href="/holidays/india/janmashtami-...'>,
#  <Selector query='//*' data='<a href="/holidays/uk/hindu-janmashta...'>,
#  <Selector query='//*' data='<tr><td colspan="2" class="nw">\xa0</td>...'>,
#  <Selector query='//*' data='<td colspan="2" class="nw">\xa0</td>'>,
#  <Selector query='//*' data='<td>Arbaeen</td>'>,
#  <Selector query='//*' data='<td><a href="/holidays/iran/arbaeen" ...'>,
#  <Selector query='//*' data='<a href="/holidays/iran/arbaeen" titl...'>,
#  <Selector query='//*' data='<tr><td colspan="2" class="nw">\xa0</td>...'>,
#  <Selector query='//*' data='<td colspan="2" class="nw">\xa0</td>'>,
#  <Selector query='//*' data='<td>Gaura Parba</td>'>,
#  <Selector query='//*' data='<td><a href="/holidays/nepal/gaura-pa...'>,
#  <Selector query='//*' data='<a href="/holidays/nepal/gaura-parba"...'>,
#  <Selector query='//*' data='<tr><td colspan="2" class="nw">\xa0</td>...'>,
#  <Selector query='//*' data='<td colspan="2" class="nw">\xa0</td>'>,
#  <Selector query='//*' data='<td>Chelum</td>'>,
#  <Selector query='//*' data='<td><a href="/holidays/pakistan/chelu...'>,
#  <Selector query='//*' data='<a href="/holidays/pakistan/chelum" t...'>,
#  <Selector query='//*' data='<tr><td colspan="2" class="nw">\xa0</td>...'>,
#  <Selector query='//*' data='<td colspan="2" class="nw">\xa0</td>'>,
#  <Selector query='//*' data='<td>Defence Day</td>'>,
#  <Selector query='//*' data='<td><a href="/holidays/pakistan/defen...'>,
#  <Selector query='//*' data='<a href="/holidays/pakistan/defence-d...'>,
#  <Selector query='//*' data='<tr><td colspan="2" class="nw">\xa0</td>...'>,
#  <Selector query='//*' data='<td colspan="2" class="nw">\xa0</td>'>,
#  <Selector query='//*' data="<td>Armed Forces' Day</td>">,
#  <Selector query='//*' data='<td><a href="/holidays/sao-tome-and-p...'>,
#  <Selector query='//*' data='<a href="/holidays/sao-tome-and-princ...'>,
#  <Selector query='//*' data='<tr><td colspan="2" class="nw">\xa0</td>...'>,
#  <Selector query='//*' data='<td colspan="2" class="nw">\xa0</td>'>,
#  <Selector query='//*' data='<td>Somhlolo Day (Independence Day)</td>'>,
#  <Selector query='//*' data='<td><a href="/holidays/swaziland/somh...'>,
#  <Selector query='//*' data='<a href="/holidays/swaziland/somhlolo...'>,
#  <Selector query='//*' data='<tr><th class="nw">Sep 7</th><th clas...'>,
#  <Selector query='//*' data='<th class="nw">Sep 7</th>'>,
#  <Selector query='//*' data='<th class="nw">Thursday</th>'>,
#  <Selector query='//*' data='<td>Independence Day</td>'>,
#  <Selector query='//*' data='<td><a href="/holidays/brazil/indepen...'>,
#  <Selector query='//*' data='<a href="/holidays/brazil/independenc...'>,
#  <Selector query='//*' data='<tr><td colspan="2" class="nw">\xa0</td>...'>,
#  <Selector query='//*' data='<td colspan="2" class="nw">\xa0</td>'>,
#  <Selector query='//*' data='<td>Genevese Fast</td>'>,
#  <Selector query='//*' data='<td><a href="/holidays/switzerland/je...'>,
#  <Selector query='//*' data='<a href="/holidays/switzerland/jeune-...'>,
#  <Selector query='//*' data='<tr><td colspan="2" class="nw">\xa0</td>...'>,
#  <Selector query='//*' data='<td colspan="2" class="nw">\xa0</td>'>,
#  <Selector query='//*' data='<td>Constitution Day</td>'>,
#  <Selector query='//*' data='<td><a href="/holidays/fiji/constitut...'>,
#  <Selector query='//*' data='<a href="/holidays/fiji/constitution-...'>,
#  <Selector query='//*' data='<tr><td colspan="2" class="nw">\xa0</td>...'>,
#  <Selector query='//*' data='<td colspan="2" class="nw">\xa0</td>'>,
#  <Selector query='//*' data='<td>Janmashtami</td>'>,
#  <Selector query='//*' data='<td><a href="/holidays/india/janmasht...'>,
#  <Selector query='//*' data='<a href="/holidays/india/janmashtami"...'>,
#  <Selector query='//*' data='<a href="/holidays/uk/hindu-janmashta...'>,
#  <Selector query='//*' data='<a href="/holidays/south-africa/hindu...'>,
#  <Selector query='//*' data='<tr><td colspan="2" class="nw">\xa0</td>...'>,
#  <Selector query='//*' data='<td colspan="2" class="nw">\xa0</td>'>,
#  <Selector query='//*' data='<td>Victory Day</td>'>,
#  <Selector query='//*' data='<td><a href="/holidays/mozambique/vic...'>,
#  <Selector query='//*' data='<a href="/holidays/mozambique/victory...'>,
#  <Selector query='//*' data='<tr><td colspan="2" class="nw">\xa0</td>...'>,
#  <Selector query='//*' data='<td colspan="2" class="nw">\xa0</td>'>,
#  <Selector query='//*' data='<td>Faro Day</td>'>,
#  <Selector query='//*' data='<td><a href="/holidays/portugal/faro-...'>,
#  <Selector query='//*' data='<a href="/holidays/portugal/faro-day"...'>,
#  <Selector query='//*' data='<tr><th class="nw">Sep 8</th><th clas...'>,
#  <Selector query='//*' data='<th class="nw">Sep 8</th>'>,
#  <Selector query='//*' data='<th class="nw">Friday</th>'>,
#  <Selector query='//*' data='<td>National Day</td>'>,
#  <Selector query='//*' data='<td><a href="/holidays/andorra/nation...'>,
#  <Selector query='//*' data='<a href="/holidays/andorra/national-d...'>,
#  <Selector query='//*' data='<tr><td colspan="2" class="nw">\xa0</td>...'>,
#  <Selector query='//*' data='<td colspan="2" class="nw">\xa0</td>'>,
#  <Selector query='//*' data='<td>Day of Asturias</td>'>,
#  <Selector query='//*' data='<td><a href="/holidays/spain/asturias...'>,
#  ...]
